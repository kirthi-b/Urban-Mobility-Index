# %%
import pandas as pd

# %%
df = pd.read_pickle('Chicago.pkl')
len(df.index)
# Out:
# 125

# %%
df2 = pd.read_pickle('DC.pkl')
len(df2.index)
# Out:
# 49

# %%
df3 = pd.read_pickle('NYC.pkl')
len(df3.index)
# Out:
# 243

# %%
df4 = pd.read_pickle('SF.pkl')
len(df4.index)
# Out:
# 110

# %%
df5 = pd.read_pickle('Ann Arbor.pkl')
len(df5.index)
# Out:
# 25

# %%
df6 = pd.read_pickle('Boulder.pkl')
len(df6.index)
# Out:
# 32

# %%
df = df.append(df2)
len(df.index)
# Out:
# 174

# %%
df = df.append(df3)

# %%
df = df.append(df4)

# %%
df = df.append(df5)
len(df.index)
# Out:
# 552

# %%
dfdf = df.append(df6)
len(df.index)
# Out:
# 584

# %%
df
# Out:
#    Rank#                           Name Walk Score Transit Score Bike Score  \
# 0      1         East Ukrainian Village         98           75         96
# 1      2                    Wicker Park         96           75         96
# 2      3                Near North Side         96           90         86
# 3      4                      West Loop         96          100         86
# 4      5              Ukrainian Village         95           70         95
# ..   ...                            ...        ...           ...        ...
# 27    28                      Keewayden         37           46         86
# 28    29                 Melody Heights         28           42         81
# 29    30                    Meadow Glen         20           31         78
# 30    31                Four Mile Creek         13           33         82
# 31    32  Devil's Thumb - Rolling Hills         13           39         49
#
# ...

# %%
df['Walk Score'] = df['Walk Score'].astype(int)

# %%
df['Walk Score'].max()
# Out:
# 100

# %%
df['Walk Score'].min()
# Out:
# 2

# %%
ax = df.hist(column='Walk Score', bins=25, grid=False, figsize=(12,8), color='#86bf91', zorder=2, rwidth=0.9)

# %%
df.to_excel (r'C:\Users\kc3493\Download\BigPickle.xlsx', index = False, header=True)
