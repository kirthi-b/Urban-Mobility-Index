# %%
# !pip install import_ipynb
# !pip install import

# %%
# To ignore unimporant system warnings
import warnings
warnings.filterwarnings("ignore")

# We will use Pandas, Numpy, and Matplotlib which is a package for visualization with Python
import pandas as pd
import numpy as np

import ipynb
import import_ipynb

# Load a required package 
# This is a library for accessing and parsing data through URLs
from urllib.parse import urlencode
import urllib.request, json 
from bs4 import BeautifulSoup # for web scraping
import requests
import fiona
import folium
import plotly.express as px
import geopandas as gpd
import adjustText as aT
import seaborn as sns # visualization styling package
import plotly.graph_objects as go
import urllib, json
import chart_studio.plotly as py
import chart_studio.tools as tls
import js2py
import os
import osmnx as ox
import ipynb
from pandas.io.json import json_normalize
import seaborn as sns
from sodapy import Socrata
from IPython.display import Image, display
import copy
from shapely.geometry import Polygon
import time
import ast
from shapely.geometry import shape
import contextily as ctx
import re
import pickle
from urllib.request import urlopen

# A magic functin that renders the figure in a notebook 
# %matplotlib inline 

import matplotlib
matplotlib.use('Agg')

from matplotlib import pyplot as plt
from shapely.geometry import Point
from shapely.geometry import MultiPoint
from shapely import wkt

from google.colab import files

# %matplotlib inline

# %%
# !wget -cq https://raw.githubusercontent.com/kirthi-b/Urban-Mobility-Index/main/Script/jscode/googlepolydecoder.js
# !wget --no-cache --backups=1 https://raw.githubusercontent.com/kirthi-b/Urban-Mobility-Index/main/Script/Functions/map_functions.ipynb
# Out:
# --2022-04-27 02:19:36--  https://raw.githubusercontent.com/kirthi-b/Urban-Mobility-Index/main/Script/Functions/map_functions.ipynb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22317455 (21M) [text/plain]
# Saving to: ‘map_functions.ipynb’
#
# map_functions.ipynb 100%[===================>]  21.28M  --.-KB/s    in 0.1s
#
# 2022-04-27 02:19:36 (176 MB/s) - ‘map_functions.ipynb’ saved [22317455/22317455]

# %%
import map_functions
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
STATE = 'CA'
CITY = 'San Francisco'

# %%
getneigh(STATE, CITY)
# Out:
# 0                                    Chinatown
# 1                                   Tenderloin
# 2                                   Polk Gulch
# 3                        Downtown-Union Square
# 4                                  North Beach
#                         ...
# 105                            Midtown Terrace
# 106                                  Lakeshore
# 107    Candlestick Point State Recreation Area
# 108                     Presidio National Park
# 109                            Treasure Island
# Name: Name, Length: 110, dtype: object

# %%
from map_functions import getnodes
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-22-4b8066138f59> in <module>()
# ----> 1 from map_functions import getnodes
#
# ImportError: cannot import name 'getnodes' from 'map_functions' (map_functions.ipynb)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
nodes = getnodes(CITY) 
neigh = getneigh(STATE, CITY)
# Out:
#                                         Name
# 0                                  Chinatown
# 1                                 Tenderloin
# 2                                 Polk Gulch
# 3                      Downtown-Union Square
# 4                                North Beach
# ..                                       ...
# 105                          Midtown Terrace
# 106                                Lakeshore
# 107  Candlestick Point State Recreation Area
# 108                   Presidio National Park
# 109                          Treasure Island
#
# [110 rows x 1 columns]
# Enter index number of neighborhood:
# 0

# %%
getmapdensity(neigh, nodes)
# Out:
#         Name Walk Score  Population      area  \
# 0  Chinatown        100        8646  0.318224
#
#                                             geometry Bus_perSqKm  \
# 0  POLYGON ((-1943329.640 -536875.296, -1943336.6...    65.99129
#
#   Bus_perThouCap  Inter_perSqKm  Inter_perThouCap
# 0       2.428869     942.732708         34.698126
